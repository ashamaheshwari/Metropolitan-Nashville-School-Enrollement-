# %%
import pandas as pd
import geopandas as gpd
import json
import requests

# %%
endpoint= 'https://api.census.gov/data/2021/acs/acs5?get=NAME,B01001_001E&for=tract:*&in=state:47&in=county:037&key=3a2e429d237f872aa3e2e39bc038ee65608e6090'

# %%
Pop_response2021 = requests.get(endpoint)

# %%
Population2021= Pop_response2021.json()
Population2021_df=pd.DataFrame.from_records(Population2021)
Population2021_df
# Out:
#                                                    0            1      2  \
# 0                                               NAME  B01001_001E  state
# 1    Census Tract 101.03, Davidson County, Tennessee         2545     47
# 2    Census Tract 101.04, Davidson County, Tennessee         3064     47
# 3    Census Tract 101.05, Davidson County, Tennessee         4895     47
# 4    Census Tract 101.06, Davidson County, Tennessee         2985     47
# ..                                               ...          ...    ...
# 170  Census Tract 195.02, Davidson County, Tennessee         3327     47
# 171  Census Tract 195.03, Davidson County, Tennessee         3259     47
# 172     Census Tract 196, Davidson County, Tennessee         3561     47
# 173    Census Tract 9801, Davidson County, Tennessee            0     47
# 174    Census Tract 9802, Davidson County, Tennessee            0     47
#
#           3       4
# 0    county   tract
# 1       037  010103
# 2       037  010104
# ...

# %%
endpointa= 'https://api.census.gov/data/2020/acs/acs5?get=NAME,B01001_001E&for=tract:*&in=state:47&in=county:037&key=3a2e429d237f872aa3e2e39bc038ee65608e6090'
Pop_response2020 = requests.get(endpointa)

# %%
Population2020= Pop_response2020.json()
Population2020_df=pd.DataFrame.from_records(Population2020)
Population2020_df
# Out:
#                                                    0            1      2  \
# 0                                               NAME  B01001_001E  state
# 1    Census Tract 190.04, Davidson County, Tennessee         4470     47
# 2    Census Tract 190.07, Davidson County, Tennessee         2904     47
# 3    Census Tract 190.08, Davidson County, Tennessee         6005     47
# 4    Census Tract 191.05, Davidson County, Tennessee         5707     47
# ..                                               ...          ...    ...
# 170  Census Tract 189.01, Davidson County, Tennessee         3280     47
# 171  Census Tract 189.02, Davidson County, Tennessee         2704     47
# 172  Census Tract 189.04, Davidson County, Tennessee         3410     47
# 173  Census Tract 189.05, Davidson County, Tennessee         3292     47
# 174  Census Tract 190.03, Davidson County, Tennessee         4427     47
#
#           3       4
# 0    county   tract
# 1       037  019004
# 2       037  019007
# ...

# %%
endpointb= 'https://api.census.gov/data/2019/acs/acs5?get=NAME,B01001_001E&for=tract:*&in=state:47&in=county:037&key=3a2e429d237f872aa3e2e39bc038ee65608e6090'
Pop_response2019 = requests.get(endpointb)
Population2019= Pop_response2019.json()
Population2019_df=pd.DataFrame.from_records(Population2019)
Population2019_df
# Out:
#                                                    0            1      2  \
# 0                                               NAME  B01001_001E  state
# 1    Census Tract 156.31, Davidson County, Tennessee        12176     47
# 2    Census Tract 158.04, Davidson County, Tennessee         4098     47
# 3    Census Tract 177.01, Davidson County, Tennessee         2466     47
# 4    Census Tract 177.02, Davidson County, Tennessee         5210     47
# ..                                               ...          ...    ...
# 157  Census Tract 156.13, Davidson County, Tennessee         5252     47
# 158  Census Tract 156.20, Davidson County, Tennessee         7262     47
# 159     Census Tract 161, Davidson County, Tennessee         2345     47
# 160     Census Tract 114, Davidson County, Tennessee         4617     47
# 161     Census Tract 138, Davidson County, Tennessee         2099     47
#
#           3       4
# 0    county   tract
# 1       037  015631
# 2       037  015804
# ...

# %%
endpointc= 'https://api.census.gov/data/2018/acs/acs5?get=NAME,B01001_001E&for=tract:*&in=state:47&in=county:037&key=3a2e429d237f872aa3e2e39bc038ee65608e6090'
Pop_response2018 = requests.get(endpointc)
Population2018= Pop_response2018.json()
Population2018_df=pd.DataFrame.from_records(Population2018)
Population2018_df
# Out:
#                                                    0            1      2  \
# 0                                               NAME  B01001_001E  state
# 1       Census Tract 133, Davidson County, Tennessee         3575     47
# 2       Census Tract 172, Davidson County, Tennessee         1455     47
# 3    Census Tract 184.08, Davidson County, Tennessee         3733     47
# 4       Census Tract 114, Davidson County, Tennessee         4650     47
# ..                                               ...          ...    ...
# 157  Census Tract 109.03, Davidson County, Tennessee         5564     47
# 158     Census Tract 139, Davidson County, Tennessee         1720     47
# 159  Census Tract 189.01, Davidson County, Tennessee         3194     47
# 160     Census Tract 178, Davidson County, Tennessee         5706     47
# 161     Census Tract 159, Davidson County, Tennessee         2765     47
#
#           3       4
# 0    county   tract
# 1       037  013300
# 2       037  017200
# ...

# %%
endpointc= 'https://api.census.gov/data/2018/acs/acs5?get=NAME,B01001_001E&for=tract:*&in=state:47&in=county:037&key=3a2e429d237f872aa3e2e39bc038ee65608e6090'
Pop_response2018 = requests.get(endpointc)
Population2018= Pop_response2018.json()
Population2018_df=pd.DataFrame.from_records(Population2018)
Population2018_df
# Out:
#                                                    0            1      2  \
# 0                                               NAME  B01001_001E  state
# 1       Census Tract 133, Davidson County, Tennessee         3575     47
# 2       Census Tract 172, Davidson County, Tennessee         1455     47
# 3    Census Tract 184.08, Davidson County, Tennessee         3733     47
# 4       Census Tract 114, Davidson County, Tennessee         4650     47
# ..                                               ...          ...    ...
# 157  Census Tract 109.03, Davidson County, Tennessee         5564     47
# 158     Census Tract 139, Davidson County, Tennessee         1720     47
# 159  Census Tract 189.01, Davidson County, Tennessee         3194     47
# 160     Census Tract 178, Davidson County, Tennessee         5706     47
# 161     Census Tract 159, Davidson County, Tennessee         2765     47
#
#           3       4
# 0    county   tract
# 1       037  013300
# 2       037  017200
# ...

# %%
Shapefile = gpd.read_file('gisMNPS_Schools_2122')
Shapefile
# Out:
#    DISTRICT                   MEMBER  TERM                           Email  \
# 0         1  Dr. Sharon Dixon Gentry  2024  gentryfordistrict1@comcast.net
# 1         3            Emily Masters  2024          Emily.Masters@mnps.org
# 2         2        Rachel Anne Elrod  2022       elrodforschools@gmail.com
# 3         4              John Little  2022            John.little@mnps.org
# 4         9            Abigail Tylor  2024          Abigail.Tylor@mnps.org
# 5         8         Gini Pupo-Walker  2022   virginia.pupo-walker@mnps.org
# 6         5         Christiane Buggs  2024                 CBuggs@mnps.org
# 7         6                Fran Bush  2022             franbush5@gmail.com
# 8         7      Freda Player-Peters  2024           Freda.Player@mnps.org
#
#           Phone                                         Photo_Link  \
# 0  615-268-5269  G:\GIS\Projects\Political_Maps\_DistrictBoard\...
# 1  615-275-6922  G:\GIS\Projects\Political_Maps\_DistrictBoard\...
# ...

# %%
Shapefile.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DISTRICT    9 non-null      int64
#  1   MEMBER      9 non-null      object
#  2   TERM        9 non-null      int64
#  3   Email       9 non-null      object
#  4   Phone       9 non-null      object
#  5   Photo_Link  9 non-null      object
#  6   Shape_Leng  9 non-null      float64
#  7   Shape_Area  9 non-null      float64
#  8   geometry    9 non-null      geometry
# dtypes: float64(2), geometry(1), int64(2), object(4)
# memory usage: 776.0+ bytes

# %%
type(Shapefile)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
Shapefile.plot();
